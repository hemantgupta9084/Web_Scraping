# %% [markdown]
# ## Importing Necessary Libraries

# %%
import requests
import json
from bs4 import BeautifulSoup
import lxml
import pandas as pd

# %% [markdown]
# ### Create Empty_list

# %%
Flipkart_Phones = []

# %% [markdown]
# ###  Scrape all Data between page 1 to 5 from Flipkart Webpage

# %%
for page in range(1,6):

    # url of the webpage
    url = f"https://www.flipkart.com/search?q=mobile+phone+5g+under+20000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={page}"
    
    # Sending HTTP Request to the website and get the response
    r = requests.get(url)
    r.status_code  #If the status_code is 200, request is succeeded. Most common status code is 200. if the request is succeded , we can get the HTML Document of the web page and start scraping.


    #Content of Webpage using content property
    html_text = r.content   

    #Converting HTML text into BeautifulSoup
    soup = BeautifulSoup(html_text,"lxml") 

    #Scrape all Data using Find_all Method
    phones = soup.find_all("div",class_="_3pLy-c row")    

    for phone in phones:
        d = {}    #Empty_Dictionary

        #Get Name of the phone
        name = "" if(phone.find("div",class_="_4rR01T")==None) else phone.find("div",class_="_4rR01T").getText()

        #Get Price of the phone
        price = "0" if(phone.find("div",class_="_30jeq3 _1_WHN1")==None) else phone.find("div",class_="_30jeq3 _1_WHN1").getText().replace("₹","").replace(",","")

        #Get Rating of the phone
        rating = "0" if(phone.find("div",class_="_3LWZlK")==None) else phone.find("div",class_="_3LWZlK").getText()

        #Get Specifications of the phone
        specifications= "" if(phone.find("ul",class_="_1xgFaf")==None) else phone.find("ul",class_="_1xgFaf").getText()

        d["Name"] = name
        d["Price"] = price
        d["Rating"] = rating
        d["Specifications"] = specifications
        Flipkart_Phones.append(d)

# %% [markdown]
# ### FlipKart Phones Web Scraping

# %%
Flipkart_Phones
# Out:
# [{'Name': 'POCO X5 5G (Wildcat Blue, 128 GB)',
#   'Price': '15999',
#   'Rating': '4.1',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Display48MP + 8MP + 2MP | 13MP Front Camera5000 mAh BatteryQualcomm Snapdragon 695 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'Infinix Note 12 Pro 5G (Force Black, 128 GB)',
#   'Price': '15999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 2 TB17.02 cm (6.7 inch) Full HD+ AMOLED Display108MP + 2MP (Depth) + 2MP (Macro) | 16MP Front Camera5000 mAh Li-ion Polymer BatteryMediatek Dimensity 810 5G Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'Infinix Note 12 Pro 5G (Snowfall, 128 GB)',
#   'Price': '15999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 2 TB17.02 cm (6.7 inch) Full HD+ AMOLED Display108MP + 2MP (Depth) + 2MP (Macro) | 16MP Front Camera5000 mAh Li-ion Polymer BatteryMediatek Dimensity 810 5G Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)',
#   'Price': '15990',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 2MP | 13MP Front Camera6000 mAh BatteryExynos 1330, Octa Core Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)',
#   'Price': '15990',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 2MP | 13MP Front Camera6000 mAh BatteryExynos 1330, Octa Core Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro 5G (Nebula Blue, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17.07 cm (6.72 inch) Full HD+ Display108MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 695 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro 5G (Nebula Blue, 128 GB)',
#   'Price': '18999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB17.07 cm (6.72 inch) Full HD+ Display108MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 695 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro 5G (Dark Matter, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17.07 cm (6.72 inch) Full HD+ Display108MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 695 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro 5G (Hyperspace, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17.07 cm (6.72 inch) Full HD+ Display108MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 695 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro 5G (Dark Matter, 128 GB)',
#   'Price': '18999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB17.07 cm (6.72 inch) Full HD+ Display108MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 695 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro 5G (Hyperspace, 128 GB)',
#   'Price': '18999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB17.07 cm (6.72 inch) Full HD+ Display108MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 695 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'Infinix HOT 20 5G (Space Blue, 64 GB)',
#   'Price': '11499',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + AI Lens | 8MP Front Camera5000 mAh Li-ion Polymer BatteryDimensity 810 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'Infinix HOT 20 5G (Blaster Green, 64 GB)',
#   'Price': '11499',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + AI Lens | 8MP Front Camera5000 mAh Li-ion Polymer BatteryDimensity 810 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'REDMI Note 12 5G (Matte Black, 128 GB)',
#   'Price': '18999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ AMOLED Display48MP + 8MP + 2MP | 13MP Front Camera5000 mAh BatteryQualcomm Snapdragon 4 Gen 1 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'REDMI Note 12 5G (Frosted Green, 128 GB)',
#   'Price': '18999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ AMOLED Display48MP + 8MP + 2MP | 13MP Front Camera5000 mAh BatteryQualcomm Snapdragon 4 Gen 1 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'REDMI Note 12 5G (Frosted Green, 128 GB)',
#   'Price': '16999',
#   'Rating': '4',
#   'Specifications': '4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ AMOLED Display48MP + 8MP + 2MP | 13MP Front Camera5000 mAh BatteryQualcomm Snapdragon 4 Gen 1 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'REDMI Note 12 5G (Matte Black, 128 GB)',
#   'Price': '16999',
#   'Rating': '4',
#   'Specifications': '4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ AMOLED Display48MP + 8MP + 2MP | 13MP Front Camera5000 mAh BatteryQualcomm Snapdragon 4 Gen 1 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'POCO X4 Pro 5G (Laser Black, 128 GB)',
#   'Price': '17999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Super AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 695 5G ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'realme 9i 5G (Soulful Blue, 128 GB)',
#   'Price': '16999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 2MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryMediatek Dimensity 810 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 9i 5G (Metallica Gold, 128 GB)',
#   'Price': '16999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 2MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryMediatek Dimensity 810 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 9i 5G (Rocking Black, 128 GB)',
#   'Price': '16999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 2MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryMediatek Dimensity 810 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'POCO X4 Pro 5G (Laser Blue, 128 GB)',
#   'Price': '17999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Super AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 695 5G ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)',
#   'Price': '18499',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 750G Processor1 Year Warranty Provided by the Manufacturer from Date of Purchase'},
#  {'Name': 'SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)',
#   'Price': '18499',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 750G Processor1 Year Warranty Provided by the Manufacturer from Date of Purchase'},
#  {'Name': 'SAMSUNG Galaxy A14 5G (Black, 128 GB)',
#   'Price': '17999',
#   'Rating': '4',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) HD+ Display50MP + 2MP | 13MP Front Camera5000 mAh Lithium Ion BatterySEC S5E8535 (Exynos 1330) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'SAMSUNG Galaxy A14 5G (Light Green, 128 GB)',
#   'Price': '17999',
#   'Rating': '4',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) HD+ Display50MP + 2MP | 13MP Front Camera5000 mAh Lithium Ion BatterySEC S5E8535 (Exynos 1330) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'Infinix Zero 5G 2023 TURBO (Pearly White, 256 GB)',
#   'Price': '16999',
#   'Rating': '4',
#   'Specifications': '8 GB RAM | 256 GB ROM | Expandable Upto 256 GB17.22 cm (6.78 inch) Full HD+ Display50MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 1080 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'POCO X4 Pro 5G (Yellow, 128 GB)',
#   'Price': '17999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Super AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 695 5G ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'SAMSUNG Galaxy A14 5G (Black, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) HD+ Display50MP + 2MP | 13MP Front Camera5000 mAh Lithium Ion BatterySEC S5E8535 (Exynos 1330) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'realme 9 5G SE (Starry Glow, 128 GB)',
#   'Price': '17999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display48MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium Polymer BatteryQualcomm Snapdragon 778G Processor1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 9 5G SE (Azure Glow, 128 GB)',
#   'Price': '17999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display48MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium Polymer BatteryQualcomm Snapdragon 778G Processor1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'POCO M4 Pro 5G (Yellow, 128 GB)',
#   'Price': '15999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 810 ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'SAMSUNG Galaxy A14 5G (Dark Red, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) HD+ Display50MP + 2MP | 13MP Front Camera5000 mAh Lithium Ion BatterySEC S5E8535 (Exynos 1330) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)',
#   'Price': '18499',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 750G Processor1 Year Warranty Provided by the Manufacturer from Date of Purchase'},
#  {'Name': 'SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)',
#   'Price': '17499',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 750G Processor1 Year Warranty Provided by the Manufacturer from Date of Purchase'},
#  {'Name': 'SAMSUNG Galaxy A14 5G (Light Green, 64 GB)',
#   'Price': '15999',
#   'Rating': '4.1',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) HD+ Display50MP + 2MP | 13MP Front Camera5000 mAh Lithium Ion BatterySEC S5E8535 (Exynos 1330) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'SAMSUNG Galaxy A14 5G (Black, 64 GB)',
#   'Price': '15999',
#   'Rating': '4.1',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) HD+ Display50MP + 2MP | 13MP Front Camera5000 mAh Lithium Ion BatterySEC S5E8535 (Exynos 1330) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'POCO M4 Pro 5G (Power Black, 128 GB)',
#   'Price': '15999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 810 ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'SAMSUNG Galaxy A14 5G (Light Green, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) HD+ Display50MP + 2MP | 13MP Front Camera5000 mAh Lithium Ion BatterySEC S5E8535 (Exynos 1330) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)',
#   'Price': '17499',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 750G Processor1 Year Warranty Provided by the Manufacturer from Date of Purchase'},
#  {'Name': 'SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)',
#   'Price': '17499',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 750G Processor1 Year Warranty Provided by the Manufacturer from Date of Purchase'},
#  {'Name': 'POCO M4 Pro 5G (Cool Blue, 128 GB)',
#   'Price': '15999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 810 ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'REDMI Note 10T 5G (Mint Green, 128 GB)',
#   'Price': '16999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM16.66 cm (6.56 inch) Full HD+ Display48MP Primary Camera + 2MP Macro Lens + 2MP Depth Sensor | 8MP Front Camera5000 mAh Lithium Polymer BatteryMediatek Dimensity 700 ProcessorMax GPU Frequency: 950 MHz, Supports GAME Turbo 3.0, UFS2.2 Storage, Reading Mode 3.0, 360 Degree Ambient Light Sensors, Supports 18W Fast Charging1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'POCO X4 Pro 5G (Yellow, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Super AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 695 5G ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'Tecno Spark 10 5G (Meta Blue, 128 GB)',
#   'Price': '14888',
#   'Rating': '4.5',
#   'Specifications': '8 GB RAM | 128 GB ROM16.76 cm (6.6 inch) Display50MP Rear Camera5000 mAh BatteryDomestic Warranty 1 Year For Handset And 6 Month For Accessories.'},
#  {'Name': 'Tecno Spark 10 5G (Meta White, 128 GB)',
#   'Price': '14990',
#   'Rating': '4.5',
#   'Specifications': '8 GB RAM | 128 GB ROM16.76 cm (6.6 inch) Display50MP Rear Camera5000 mAh BatteryDomestic Warranty 1 Year For Handset And 6 Month For Accessories.'},
#  {'Name': 'vivo Y565G (Orange Shimmer, 128 GB)',
#   'Price': '19989',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 16MP Front Camera5000 mAh BatteryMTK Dimensity 700 Processor1 Year Manufacturer Warranty for Handset and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'Infinix Zero 5G (Skylight Orange, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 256 GB17.22 cm (6.78 inch) Full HD+ Display48 MP + 13 MP Portrait Lens + 2 MP Bokeh Lens | 16MP Front Camera5000 mAh Li-ion Polymer BatteryMediatek Dimensity 900 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'POCO X4 Pro 5G (Laser Black, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Super AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 695 5G ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'vivo T1 5G (Starlight Black, 128 GB)',
#   'Price': '19990',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium BatteryQualcomm Snapdragon 695 Processor1 Year Handset and 6 Months Accessories'},
#  {'Name': 'POCO M4 Pro 5G (Cool Blue, 128 GB)',
#   'Price': '16999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 810 ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'vivo Y565G (Black Engine, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 16MP Front Camera5000 mAh BatteryMTK Dimensity 700 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'Infinix Zero 5G (Horizon Blue, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 256 GB17.22 cm (6.78 inch) Full HD+ Display48 MP + 13 MP Portrait Lens + 2 MP Bokeh Lens | 16MP Front Camera5000 mAh Li-ion Polymer BatteryMediatek Dimensity 900 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'Tecno Pova Neo 5G (Sprint Blue, 128 GB)',
#   'Price': '15799',
#   'Rating': '3.9',
#   'Specifications': '4 GB RAM | 128 GB ROM | Expandable Upto 1 TB17.27 cm (6.8 inch) Full HD+ Display50MP Rear Camera | 8MP Front Camera6000 mAh BatteryMediaTek Dimensity 810 MT6833 Processor1 Year Manufacturer Warranty for Handset and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'POCO M4 Pro 5G (Yellow, 128 GB)',
#   'Price': '16999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 810 ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'Tecno Spark 10 5G (Meta White, 128 GB)',
#   'Price': '14500',
#   'Rating': '4.5',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) HD+ Display50MP Rear Camera | 8MP Front Camera5000 mAh BatteryMediatek Dimensity 6020 Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'POCO X4 Pro 5G (Laser Blue, 128 GB)',
#   'Price': '19999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Super AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 695 5G ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'REDMI Note 10T 5G (Metallic Blue, 64 GB)',
#   'Price': '13999',
#   'Rating': '4.3',
#   'Specifications': '4 GB RAM | 64 GB ROM16.66 cm (6.56 inch) Full HD+ Display48MP Primary Camera + 2MP Macro Lens + 2MP Depth Sensor | 8MP Front Camera5000 mAh Lithium Polymer BatteryMediatek Dimensity 700 ProcessorMax GPU Frequency: 950 MHz, Supports GAME Turbo 3.0, UFS2.2 Storage, Reading Mode 3.0, 360 Degree Ambient Light Sensors, Supports 18W Fast Charging1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'Infinix Note 30 5G (Magic Black, 256 GB)',
#   'Price': '15999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 256 GB ROM | Expandable Upto 2 TB17.22 cm (6.78 inch) Full HD+ Display108 MP + 2 MP+ AI Lens | 16MP Front Camera5000 mAh Li-ion Polymer BatteryDimensity 6080 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'Tecno Camon 20 Pro (Serenity Blue, 128 GB)',
#   'Price': '19990',
#   'Rating': '4.6',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Display64MP + 2MP + 2MP | 32MP Front Camera5000 mAh BatteryMediatek Dimensity 8050 Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'POCO M4 5G (Cool Blue, 64 GB)',
#   'Price': '11999',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion Polymer BatteryMediatek Dimensity 700 Processor1 Year Warranty for Handset and 6 Months for Accessories'},
#  {'Name': 'POCO M4 5G (Yellow, 128 GB)',
#   'Price': '13999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion Polymer BatteryMediatek Dimensity 700 Processor1 Year Warranty for Handset and 6 Months for Accessories'},
#  {'Name': 'Infinix Zero 5G 2023 (Submariner Black, 128 GB)',
#   'Price': '14999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 256 GB17.22 cm (6.78 inch) Full HD+ Display50MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 920 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'Infinix Zero 5G 2023 (Pearly White, 128 GB)',
#   'Price': '14999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 256 GB17.22 cm (6.78 inch) Full HD+ Display50MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 920 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'POCO M4 5G (Power Black, 64 GB)',
#   'Price': '11999',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion Polymer BatteryMediatek Dimensity 700 Processor1 Year Warranty for Handset and 6 Months for Accessories'},
#  {'Name': 'Infinix HOT 20 5G (Racing Black, 64 GB)',
#   'Price': '11499',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + AI Lens | 8MP Front Camera5000 mAh Li-ion Polymer BatteryDimensity 810 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'Infinix Zero 5G 2023 (Coral Orange, 128 GB)',
#   'Price': '14999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 256 GB17.22 cm (6.78 inch) Full HD+ Display50MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 920 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'realme 9i 5G (Rocking Black, 64 GB)',
#   'Price': '14999',
#   'Rating': '4.5',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 2MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryMediatek Dimensity 810 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 9i 5G (Metallica Gold, 64 GB)',
#   'Price': '14999',
#   'Rating': '4.5',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 2MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryMediatek Dimensity 810 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 9i 5G (Soulful Blue, 64 GB)',
#   'Price': '14999',
#   'Rating': '4.5',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 2MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion BatteryMediatek Dimensity 810 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'POCO M4 5G (Yellow, 64 GB)',
#   'Price': '11999',
#   'Rating': '4.2',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion Polymer BatteryMediatek Dimensity 700 Processor1 Year Warranty for Handset and 6 Months for Accessories'},
#  {'Name': 'Infinix Hot 20 5G (Racing Black, 128 GB)',
#   'Price': '13499',
#   'Rating': '4.1',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + AI Lens | 8MP Front Camera5000 mAh Li-ion Polymer BatteryDimensity 810 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'Infinix Hot 20 5G (Space Blue, 128 GB)',
#   'Price': '13499',
#   'Rating': '4.1',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + AI Lens | 8MP Front Camera5000 mAh Li-ion Polymer BatteryDimensity 810 Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'POCO M4 Pro 5G (Cool Blue, 64 GB)',
#   'Price': '11999',
#   'Rating': '4.3',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 810 ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'POCO M4 5G (Power Black, 128 GB)',
#   'Price': '13999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion Polymer BatteryMediatek Dimensity 700 Processor1 Year Warranty for Handset and 6 Months for Accessories'},
#  {'Name': 'POCO M4 5G (Cool Blue, 128 GB)',
#   'Price': '13999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP | 8MP Front Camera5000 mAh Lithium Ion Polymer BatteryMediatek Dimensity 700 Processor1 Year Warranty for Handset and 6 Months for Accessories'},
#  {'Name': 'Infinix Note 12 5G (Snowfall, 64 GB)',
#   'Price': '14999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 64 GB ROM | Expandable Upto 2 TB17.02 cm (6.7 inch) Full HD+ AMOLED Display50 MP + 2 MP Depth Lens + AI Lens | 16MP Front Camera5000 mAh Li-ion Polymer BatteryMediatek Dimensity 810 5G Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'POCO M4 Pro 5G (Yellow, 64 GB)',
#   'Price': '11999',
#   'Rating': '4.3',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediatek Dimensity 810 ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'Infinix Note 12 5G (Force Black, 64 GB)',
#   'Price': '14999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 64 GB ROM | Expandable Upto 2 TB17.02 cm (6.7 inch) Full HD+ AMOLED Display50 MP + 2 MP Depth Lens + AI Lens | 16MP Front Camera5000 mAh Li-ion Polymer BatteryMediatek Dimensity 810 5G Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'realme 9 5G (Meteor Black, 64 GB)',
#   'Price': '13499',
#   'Rating': '4.5',
#   'Specifications': '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.51 cm (6.5 inch) Full HD+ Display48MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium Polymer BatteryMediatek Dimensity 810 Processor1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'REDMI Note 10T 5G (Mint Green, 64 GB)',
#   'Price': '14999',
#   'Rating': '4.3',
#   'Specifications': '4 GB RAM | 64 GB ROM16.66 cm (6.56 inch) Full HD+ Display48MP Primary Camera + 2MP Macro Lens + 2MP Depth Sensor | 8MP Front Camera5000 mAh Lithium Polymer BatteryMediatek Dimensity 700 ProcessorMax GPU Frequency: 950 MHz, Supports GAME Turbo 3.0, UFS2.2 Storage, Reading Mode 3.0, 360 Degree Ambient Light Sensors, Supports 18W Fast Charging1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'vivo T2 5G (Velocity Wave, 128 GB)',
#   'Price': '20999',
#   'Rating': '4.4',
#   'Specifications': '8 GB RAM | 128 GB ROM16.21 cm (6.38 inch) Full HD+ Display64 MP (OIS) + 2MP | 16MP Front Camera4500 mAh BatterySnapdragon 695 Processor1 Year of Device & 6 Months for Inbox Accessories'},
#  {'Name': 'POCO X5 Pro 5G (Horizon Blue, 256 GB)',
#   'Price': '22999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 256 GB ROM16.94 cm (6.67 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 778G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories'},
#  {'Name': 'POCO X5 Pro 5G (Astral Black, 256 GB)',
#   'Price': '22999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 256 GB ROM16.94 cm (6.67 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 778G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories'},
#  {'Name': 'realme GT 2 (Paper White, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM16.81 cm (6.62 inch) Full HD+ AMOLED Display50MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 888 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme GT 2 (Steel Black, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 128 GB ROM16.81 cm (6.62 inch) Full HD+ AMOLED Display50MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 888 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'POCO X5 Pro 5G (Yellow, 256 GB)',
#   'Price': '22999',
#   'Rating': '4.3',
#   'Specifications': '8 GB RAM | 256 GB ROM16.94 cm (6.67 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 778G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories'},
#  {'Name': 'REDMI Note 12 Pro 5G (Glacier Blue, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ AMOLED Display50MP (OIS) + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium Polymer BatteryMediatek Dimensity 1080 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'MOTOROLA g82 5G (Meterorite Grey, 128 GB)',
#   'Price': '21499',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium BatteryQualcomm Snapdragon 695 5G Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'POCO F4 5G (Night Black, 256 GB)',
#   'Price': '24999',
#   'Rating': '4.3',
#   'Specifications': '12 GB RAM | 256 GB ROM16.94 cm (6.67 inch) Full HD+ Display64MP + 8MP + 2MP | 20MP Front Camera4500 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 870 Processor2 Years Brand Warranty'},
#  {'Name': 'POCO X5 Pro 5G (Horizon Blue, 128 GB)',
#   'Price': '20999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 778G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories'},
#  {'Name': 'MOTOROLA g82 5G (White Lily, 128 GB)',
#   'Price': '21499',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium BatteryQualcomm Snapdragon 695 5G Processor1 Year on Handset and 6 Months on Accessories'},
#  {'Name': 'REDMI Note 12 Pro 5G (Glacier Blue, 128 GB)',
#   'Price': '24999',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ AMOLED Display50MP (OIS) + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium Polymer BatteryMediatek Dimensity 1080 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'realme 10 Pro+ 5G (Nebula Blue, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.4',
#   'Specifications': '8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryMediatek Dimensity 1080 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro+ 5G (Hyperspace, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.4',
#   'Specifications': '8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryMediatek Dimensity 1080 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro+ 5G (Dark Matter, 128 GB)',
#   'Price': '22999',
#   'Rating': '4.4',
#   'Specifications': '6 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryMediatek Dimensity 1080 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro+ 5G (Hyperspace, 128 GB)',
#   'Price': '22999',
#   'Rating': '4.4',
#   'Specifications': '6 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryMediatek Dimensity 1080 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro+ 5G (Dark Matter, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.4',
#   'Specifications': '8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryMediatek Dimensity 1080 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'realme 10 Pro+ 5G (Nebula Blue, 128 GB)',
#   'Price': '22999',
#   'Rating': '4.4',
#   'Specifications': '6 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryMediatek Dimensity 1080 5G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories'},
#  {'Name': 'POCO X5 Pro 5G (Yellow, 128 GB)',
#   'Price': '20999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 778G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories'},
#  {'Name': 'SAMSUNG Galaxy A23 5G (Light Blue, 128 GB)',
#   'Price': '21999',
#   'Rating': '4.1',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 5MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 695 (SM6375) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'SAMSUNG Galaxy A23 5G (Silver, 128 GB)',
#   'Price': '21999',
#   'Rating': '4.1',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 5MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 695 (SM6375) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'POCO X5 Pro 5G (Astral Black, 128 GB)',
#   'Price': '20999',
#   'Rating': '4.3',
#   'Specifications': '6 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ Display108MP + 8MP + 2MP | 16MP Front Camera5000 mAh BatteryQualcomm Snapdragon 778G Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories'},
#  {'Name': 'SAMSUNG Galaxy A23 5G (Orange, 128 GB)',
#   'Price': '21999',
#   'Rating': '4.1',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 5MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 695 (SM6375) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'vivo T1 Pro 5G (Turbo Black, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.4',
#   'Specifications': '6 GB RAM | 128 GB ROM16.36 cm (6.44 inch) Full HD+ AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera4700 mAh Lithium BatteryQualcomm Snapdragon 778G 5G Mobile Platform Processor1 Year Handset and 6 Months Accessories'},
#  {'Name': 'Xiaomi 11Lite NE (Vinyl Black, 128 GB)',
#   'Price': '21695',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.64 cm (6.55 inch) Full HD+ Display64MP + 8MP + 5MP | 20MP Front Camera4250 mAh BatteryQualcomm Snapdragon 778G ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories'},
#  {'Name': 'OPPO F21s Pro 5G (Starlight Black, 128 GB)',
#   'Price': '26399',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.33 cm (6.43 inch) Full HD+ E3 Super AMOLED Display64MP + 2MP + 2MP | 16MP + 2MP Dual Front Camera4500 mAh BatteryQualcomm SM6225 Snapdragon 680 4G (6 nm) Processor12 months'},
#  {'Name': 'vivo V23e 5G (Sunshine Gold, 128 GB)',
#   'Price': '24199',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.36 cm (6.44 inch) Full HD+ AMOLED Display50MP + 8MP + 2MP | 44MP Front Camera4050 mAh Lithium BatteryMediatek Dimensity 810 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'vivo T1 Pro 5G (Turbo Cyan, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.4',
#   'Specifications': '6 GB RAM | 128 GB ROM16.36 cm (6.44 inch) Full HD+ AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera4700 mAh Lithium BatteryQualcomm Snapdragon 778G 5G Mobile Platform Processor1 Year Handset and 6 Months Accessories'},
#  {'Name': 'vivo T1 Pro 5G (Turbo Black, 128 GB)',
#   'Price': '24999',
#   'Rating': '4.4',
#   'Specifications': '8 GB RAM | 128 GB ROM16.36 cm (6.44 inch) Full HD+ AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera4700 mAh Lithium BatteryQualcomm Snapdragon 778G 5G Mobile Platform Processor1 Year Handset and 6 Months Accessories'},
#  {'Name': 'Mi 10T (Cosmic Black, 128 GB)',
#   'Price': '37999',
#   'Rating': '4.1',
#   'Specifications': '8 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ Display64MP + 13MP + 5MP | 20MP Front Camera5000 mAh Li-ion Polymer BatteryQualcomm Snapdragon 865 Processor144Hz Intelligent AdaptiveSync Display33W Dual Split Flash Charge1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-box Accessories'},
#  {'Name': 'OnePlus Nord (Gray Onyx, 64 GB)',
#   'Price': '23990',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 64 GB ROM16.36 cm (6.44 inch) Full HD+ Display48MP + 8MP | 32MP + 8MP Dual Front Camera4115 mAh BatteryQualcomm® Snapdragon™ 765G Processor1 Year'},
#  {'Name': 'Xiaomi 11i Hypercharge 5G (Stealth Black, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ AMOLED Display108MP + 8MP + 2MP | 16MP Front Camera4500 mAh Li-Polymer BatteryMediatek Dimensity 920 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'Xiaomi 11i Hypercharge 5G (Purple Mist, 128 GB)',
#   'Price': '23999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ AMOLED Display108MP + 8MP + 2MP | 16MP Front Camera4500 mAh Li-Polymer BatteryMediatek Dimensity 920 Processor1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In the Box Accessories'},
#  {'Name': 'Mi 11X (Lunar White, 128 GB)',
#   'Price': '23990',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ Display48MP + 8MP + 5MP | 20MP Front Camera4520 mAh BatteryQualcomm Snapdragon 870 Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-box Accessories'},
#  {'Name': 'POCO X4 Pro 5G (Yellow, 64 GB)',
#   'Price': '22999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 64 GB ROM | Expandable Upto 1 TB16.94 cm (6.67 inch) Full HD+ Super AMOLED Display64MP + 8MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 695 5G ProcessorOne Year for Handset, 6 Months for Accessories'},
#  {'Name': 'SAMSUNG Galaxy A23 5G (Light Blue, 128 GB)',
#   'Price': '23999',
#   'Rating': '3.8',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.76 cm (6.6 inch) Full HD+ Display50MP + 5MP | 8MP Front Camera5000 mAh Lithium Ion BatteryQualcomm Snapdragon 695 (SM6375) Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories'},
#  {'Name': 'Xiaomi 11Lite NE (Jazz Blue, 128 GB)',
#   'Price': '24999',
#   'Rating': '4.2',
#   'Specifications': '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.64 cm (6.55 inch) Full HD+ Display64MP + 8MP + 5MP | 20MP Front Camera4250 mAh BatteryQualcomm Snapdragon 778G ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories'},
#  {'Name': 'Xiaomi 11Lite NE (Jazz Blue, 128 GB)',
#   'Price': '23978',
#   'Rating': '4.2',
#   'Specifications': '8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.64 cm (6.55 inch) Full HD+ Display64MP + 8MP + 5MP | 20MP Front Camera4250 mAh BatteryQualcomm Snapdragon 778G ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories'},
#  {'Name': 'vivo T1 5G (Rainbow Fantasy, 128 GB)',
#   'Price': '15990',
#   'Rating': '4.3',
#   'Specifications': '4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16.71 cm (6.58 inch) Full HD+ Display50MP + 2MP + 2MP | 16MP Front Camera5000 mAh Lithium BatteryTurbo Processor Snapdragon 695 Processor1 Year Handset and 6 Months Accessories'}]

# %% [markdown]
# ### Convert To Json Format

# %%
f = open("Flipkart Phones Web Scraping.json","w")
json.dump(Flipkart_Phones,f,indent=4)

# %% [markdown]
# #### Import Data

# %%
file = pd.DataFrame(Flipkart_Phones,columns=["Name","Price","Rating","Specifications"])
file
# Out:
#                                              Name  Price Rating  \
# 0               POCO X5 5G (Wildcat Blue, 128 GB)  15999    4.1
# 1    Infinix Note 12 Pro 5G (Force Black, 128 GB)  15999    4.1
# 2       Infinix Note 12 Pro 5G (Snowfall, 128 GB)  15999    4.1
# 3       SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)  15990    4.2
# 4      SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)  15990    4.2
# ..                                            ...    ...    ...
# 115                POCO X4 Pro 5G (Yellow, 64 GB)  22999    4.2
# 116    SAMSUNG Galaxy A23 5G (Light Blue, 128 GB)  23999    3.8
# 117          Xiaomi 11Lite NE (Jazz Blue, 128 GB)  24999    4.2
# 118          Xiaomi 11Lite NE (Jazz Blue, 128 GB)  23978    4.2
# 119          vivo T1 5G (Rainbow Fantasy, 128 GB)  15990    4.3
#
#                                         Specifications
# 0    6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 1    8 GB RAM | 128 GB ROM | Expandable Upto 2 TB17...
# 2    8 GB RAM | 128 GB ROM | Expandable Upto 2 TB17...
# 3    6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 4    6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# ..                                                 ...
# 115  6 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....
# 116  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 117  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 118  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 119  4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
#
# [120 rows x 4 columns]

# %% [markdown]
# ### Convert To CSV File

# %%
file.to_csv('Flipkart phones Details.csv')
